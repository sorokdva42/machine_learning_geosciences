# %% [markdown]
# # ___
#
# # [ Machine Learning in Geosciences ]
#
# ## **Test 2 solution**
#
# *Author: ...*
#
# *Date: ...*
#
# ___

# %% [markdown]
# ### 1.1. The Problem
#
# Classify glacier lakes and ice in Greenland using Sentinel-2 imagery. The categories are:
#
#     1 = Glacier lakes
#
#     2 = Ice
#
# This classification helps to understand spatial patterns of glacial melt, especially as water increase the speed of glacier ice melt.
#
# ### 1.2. Objective:
# **Build a binary classification machine learning classifier to map galcier surface into glacier lakes and glacier ice  from Sentinel-2 imagery using reference vector data. The focus is on creating a reliable predictive model, not on generating full prediction maps.**
#
# ### 1.3. Assumptions
# * The problem is binary classification using spectral and possibly derived features.
# * The input data is batch data — no streaming, so batch learning methods apply.
# * All pixels with visible ice and/or snow are expected to be glacier ice.
# * The Sentinel-2 imagery contains useful spectral bands.
# * Spatial and class imbalances may exist.
#
# ### 1.4. Expected Deliverables
# A complete ML workflow to build and evaluate a model with the following steps:
#
# **Step 1: Task Description (Already completed)**
#
# **Step 2: Exploratory Data Analysis (EDA)**
# - Import Sentinel-2 image (10 bands).
# - Import vector data with an attribute label.
# - Check for class imbalance.
#
# **Step 3: Data Preparation**
# - Extract features from imagery using training polygons.
# - Handle missing data, if any.
# - Split data into train/test sets to avoid leakage.
#
# **Step 4: Model Selection and Training**
# - Consider both linear (e.g. Logistic Regression) and non-linear ML models.
# - Determine if non-linearity improves the classification of lakes.
# - Train models using cross-validation.
#
# **Step 5: Model Fine-tuning**
# - Perform hyperparameter optimization.
# - Evaluate performance.
#
# **Step 6: Results Interpretation**
# - Report:
#     * Model  accuracy
#     * Generalization gap (train vs test accuracy)
#
# - Discuss:
#     * Limitations
#     * Potential improvements
# ___

# %% [markdown]
# ### Sentinel-2 image

# %% [markdown]
# ![image.png](attachment:14d7cb46-4a15-44ea-a928-7511610cfeda.png)

# %% [markdown]
# **Sentinel-2 image with reference labels:**
#
#     1 = Lakes (blue polygons)
#
#     2 = Glacier ice (green polygons)

# %% [markdown]
# ![image.png](attachment:81f3059b-f058-4213-a65a-e3797c004b8f.png)

# %% [markdown]
# ![image.png](attachment:0942d026-1a9e-451c-a26c-174bf127e93e.png)

# %% [markdown]
# ### Input data description

# %% [markdown]
# * Sentinel-2 image (10 bands)
#
# * Reference vector file with a label attribute (1: Lakes, 2: Glacier ice)

# %%
# Download data from Google Drive: 
# https://drive.google.com/drive/folders/1KEn3q8nG3NrJ9qO_utiwWPp9K_7WNTs-?usp=sharing 

# file: S2_20220827T152809_T22WEC_20m_subset.tif (~72MB)
# file: glacier_lakes_lables.gpkg (~200KB)

# %%
# Continue your work here
pass

# %% [markdown]
# Submit your solution (Jupyter Notebook with your steps description - justification) to email: lukas.brodsky@natur.cuni.cz
